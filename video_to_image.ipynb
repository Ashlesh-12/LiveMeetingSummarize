# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor12458j/LiveMeetingSummarize/blob/Balaji/video_to_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import os
import time
from google.colab.patches import cv2_imshow

video_path = "/content/168193-838481303_small.mp4"
output_folder = "frames"

# Create output folder if not exists
os.makedirs(output_folder, exist_ok=True)
# Load video
cap = cv2.VideoCapture(video_path)
# Check if video opened succesfully
if not cap.isOpened():
  print("Error: Could not open video.")
  exit()
frame_count = 0
max_frames=10
while frame_count<max_frames:
    ret, frame = cap.read()
    if not ret:
        break  # Video ended

    # # Save frame as image
    # frame_filename=os.path.join(output_folder,f"frame_{frame_count:03d}.jpg")
    # cv2.imwrite(frame_filename, frame)
    # print(f"Saved {frame_filename}")

    cv2_imshow(frame)
    time.sleep(0.1)

    frame_count += 1
# Release resources
cap.release()
cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture("/content/168193-838481303_small.mp4")
print("Total frames:", cap.get(cv2.CAP_PROP_FRAME_COUNT))
cap.release()
