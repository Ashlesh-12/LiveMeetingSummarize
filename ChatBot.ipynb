# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor12458j/LiveMeetingSummarize/blob/Monica/ChatBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Chatbot:Hi! I am your Chatbot")
while True:
  user = input("You:")

  if user.lower() == "hi":
    print("Chatbot:Hello! How are you?")
  elif user.lower() == "how are you":
    print("Chatbot:Iam Good thank you")
  elif user.lower() == "bye":
    print("Chatbot:Bye have a nice day")
    break
  else:
    print("chatbot:Sorry,I dont understand")
# Out:
# Chatbot:Hi! I am your Chatbot
# You:hi
# Chatbot:Hello! How are you?
# You:how are you
# Chatbot:Iam Good thank you
# You:hi
# Chatbot:Hello! How are you?
# You:hi
# Chatbot:Hello! How are you?
# You:bye
# Chatbot:Bye have a nice day
